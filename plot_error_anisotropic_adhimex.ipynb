# %% [markdown]
# # Plotting the error connected to the anisotropic AdHImEx runs from 15-09-2026
#
# 15-09-2026, 16-09-2026

# %%
# FULL REVOLUTION RESULTS

# Constant uv

# anisotropic

l2_c_a_640 = 5.010561e-05
l2_c_a_1280 = 6.330311e-05 # less accurate with higher resolution (but not by a lot, and it is already quite accurate)
l2_c_a_2560 = 5.313806e-04 # LESS ACCURATE WITH HIGHER RESOLUTION
#--> These error increases could be due to the larger number of implicit solves with the same tolerance with the same C. Error floor (at about E-5) accumulates over time, increasing the error.
#--> I might want to test the error convergence perhaps with velocity changing rather than dt changing - check with Hilary. 

# isotropic

l2_c_na_640 = 3.223905e-04
l2_c_na_1280 = 1.892420e-03 # LESS ACCURATE WITH HIGHER RESOLUTION
l2_c_na_2560 = 1.241532e-03 # more accurate with higher resolution (but not by a lot)

########################################################

# Swiftnondiv (even higher C (second-order implicit) and second-order accuracy for velocity)

# anisotropic

l2_s_a_640 = 4.057399e-04
l2_s_a_1280 = 1.163761e-04 # more accurate with higher resolution (but not by a lot)
l2_s_a_2560 = 2.385930e-04 # less accurate (but not by a lot)

# isotropic

l2_s_na_640 = 4.076473e-04
l2_s_na_1280 = 1.167258e-04 # more accurate with higher resolution (but not by a lot)
l2_s_na_2560 = 2.576709e-04 # less accurate (but not by a lot)



########################################################

# Constant v (grid is changing in y, not in x)

# anisotropic

l2_cv_a_640 = 5.947354e-05
l2_cv_a_1280 = 9.528227e-05 # less accurate with higher resolution (but not by a lot)
l2_cv_a_2560 = 6.510719e-04 # less accurate with higher resolution

# isotropic

l2_cv_na_640 = 2.939825e-03
l2_cv_na_1280 = 1.503317e-03 # more accurate with higher resolution (but not by a lot)
l2_cv_na_2560 = 5.731537e-04 # more accurate with higher resolution (but not by a lot)


########################################################

# Constant u (grid is changing in y, not in x)

# anisotropic

l2_cu_a_640 = 2.284445e-06
l2_cu_a_1280 = 2.456698e-07 # more accurate with higher resolution
l2_cu_a_2560 = 2.945878e-08 # more accurate with higher resolution

# isotropic (correct: the same as anisotropic)

l2_cu_na_640 = 2.284445e-06
l2_cu_na_1280 = 2.456698e-07
l2_cu_na_2560 = 2.945878e-08

# %% [markdown]
# Test with constant uv with even higher C in y? Not just a 10 factor difference with C in x but 20?

# %% [markdown]
# 16-09-2026 - Another idea: calculate the error after only a small number of nt. So there is less error accumulation. Do not run for a whole revolution. I can only do this for the constant u and v (and uv) runs, not for swift, but worth checking for those.

# %% [markdown]
# # Running for t = 0.4 (minimum time to avoid error saturation)
#
# 17-09-2026

# %% [markdown]
# RDG-HOME+ma836128@UOR002E523383FB MINGW64 ~/OneDrive - University of Reading/Documents/phd/code/2Dadvection (main)
# $ ./convergence_anisotropic_adhimex.sh
# === Running: python run_model.py config_constantuv_sine_unif_anis_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantuv_sine_unif_anis_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(9.581296214764763e-07), np.float64(0.9999990418703781))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_anis_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_anis_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuv_sine_unif_anis_ny1280dt0_2nt2\config_constantuv_sine_unif_anis_ny1280dt0_2nt2.yml
# 4.9746477310711125e-08
# Done
# === Running: python run_model.py config_constantuv_sine_unif_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantuv_sine_unif_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(9.57291958121387e-07), np.float64(0.999999042708042))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuv_sine_unif_ny1280dt0_2nt2\config_constantuv_sine_unif_ny1280dt0_2nt2.yml
# 1.0320066331553721e-07
# Done
# === Running: python run_model.py config_constantuv_sine_unif_anis_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantuv_sine_unif_anis_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.0001435530342333954), np.float64(0.9998564469657667))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_anis_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_anis_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuv_sine_unif_anis_ny640dt0_4nt1\config_constantuv_sine_unif_anis_ny640dt0_4nt1.yml
# 1.9924925526156543e-07
# Done
# === Running: python run_model.py config_constantuv_sine_unif_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantuv_sine_unif_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.00014354985945729969), np.float64(0.9998564501405428))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuv_sine_unif_ny640dt0_4nt1\config_constantuv_sine_unif_ny640dt0_4nt1.yml
# 4.127842019095112e-07
# Done
# === Running: python run_model.py config_constantuv_sine_unif_anis_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantuv_sine_unif_anis_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(3.42236502507576e-05), np.float64(0.9999657763497483))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_anis_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_anis_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuv_sine_unif_anis_ny2560dt0_1nt4\config_constantuv_sine_unif_anis_ny2560dt0_1nt4.yml
# 1.243411840878405e-08
# Done
# === Running: python run_model.py config_constantuv_sine_unif_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantuv_sine_unif_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(3.4223669016221546e-05), np.float64(0.9999657763309838))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuv_sine_unif_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuv_sine_unif_ny2560dt0_1nt4\config_constantuv_sine_unif_ny2560dt0_1nt4.yml
# 2.5801233357940707e-08
# Done
# === Running: python run_model.py config_constantv_sine_unif_anis_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantv_sine_unif_anis_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.0006023585128865093), np.float64(0.9993976414871135))
# Minimum and maximum C over all times: 2.56, 2.56
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_anis_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_anis_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantv_sine_unif_anis_ny640dt0_4nt1\config_constantv_sine_unif_anis_ny640dt0_4nt1.yml
# 2.3083857685525355e-07
# Done
# === Running: python run_model.py config_constantv_sine_unif_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantv_sine_unif_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.0006023592725776644), np.float64(0.9993976407274218))
# Minimum and maximum C over all times: 2.56, 2.56
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantv_sine_unif_ny640dt0_4nt1\config_constantv_sine_unif_ny640dt0_4nt1.yml
# 5.3236879391009844e-08
# Done
# === Running: python run_model.py config_constantv_sine_unif_anis_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantv_sine_unif_anis_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(0.0001514603811666455), np.float64(0.999848539618833))
# Minimum and maximum C over all times: 2.56, 2.56
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_anis_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_anis_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantv_sine_unif_anis_ny1280dt0_2nt2\config_constantv_sine_unif_anis_ny1280dt0_2nt2.yml
# 5.7711838351816394e-08
# Done
# === Running: python run_model.py config_constantv_sine_unif_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantv_sine_unif_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(0.0001514603690332141), np.float64(0.9998485396309671))
# Minimum and maximum C over all times: 2.56, 2.56
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantv_sine_unif_ny1280dt0_2nt2\config_constantv_sine_unif_ny1280dt0_2nt2.yml
# 1.3310007031515332e-08
# Done
# === Running: python run_model.py config_constantv_sine_unif_anis_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantv_sine_unif_anis_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(3.775088943247194e-05), np.float64(0.9999622491105706))
# Minimum and maximum C over all times: 2.56, 2.56
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_anis_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_anis_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantv_sine_unif_anis_ny2560dt0_1nt4\config_constantv_sine_unif_anis_ny2560dt0_1nt4.yml
# 1.4428096727700138e-08
# Done
# === Running: python run_model.py config_constantv_sine_unif_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantv_sine_unif_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(3.7750891570355605e-05), np.float64(0.9999622491084303))
# Minimum and maximum C over all times: 2.56, 2.56
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantv_sine_unif_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantv_sine_unif_ny2560dt0_1nt4\config_constantv_sine_unif_ny2560dt0_1nt4.yml
# 3.3275509637461206e-09
# Done
# === Running: python run_model.py config_constantu_sine_unif_anis_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantu_sine_unif_anis_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.00014948178131463547), np.float64(0.9998505182186853))
# Minimum and maximum C over all times: 0.256, 0.256
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_anis_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_anis_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantu_sine_unif_anis_ny640dt0_4nt1\config_constantu_sine_unif_anis_ny640dt0_4nt1.yml
# 9.13780190087281e-09
# Done
# === Running: python run_model.py config_constantu_sine_unif_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantu_sine_unif_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.00014948178131463547), np.float64(0.9998505182186853))
# Minimum and maximum C over all times: 0.256, 0.256
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantu_sine_unif_ny640dt0_4nt1\config_constantu_sine_unif_ny640dt0_4nt1.yml
# 9.13780190087281e-09
# Done
# === Running: python run_model.py config_constantu_sine_unif_anis_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantu_sine_unif_anis_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(1.5938242994751093e-06), np.float64(0.9999984061757006))
# Minimum and maximum C over all times: 0.256, 0.256
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_anis_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_anis_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantu_sine_unif_anis_ny1280dt0_2nt2\config_constantu_sine_unif_anis_ny1280dt0_2nt2.yml
# 9.826794221508725e-10
# Done
# === Running: python run_model.py config_constantu_sine_unif_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantu_sine_unif_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(1.5938242994751093e-06), np.float64(0.9999984061757006))
# Minimum and maximum C over all times: 0.256, 0.256
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantu_sine_unif_ny1280dt0_2nt2\config_constantu_sine_unif_ny1280dt0_2nt2.yml
# 9.826794221508725e-10
# Done
# === Running: python run_model.py config_constantu_sine_unif_anis_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantu_sine_unif_anis_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(3.4498153824951956e-05), np.float64(0.999965501846175))
# Minimum and maximum C over all times: 0.256, 0.256
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_anis_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_anis_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantu_sine_unif_anis_ny2560dt0_1nt4\config_constantu_sine_unif_anis_ny2560dt0_1nt4.yml
# 1.1783511166847798e-10
# Done
# === Running: python run_model.py config_constantu_sine_unif_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantu_sine_unif_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(3.4498153824951956e-05), np.float64(0.999965501846175))
# Minimum and maximum C over all times: 0.256, 0.256
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantu_sine_unif_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantu_sine_unif_ny2560dt0_1nt4\config_constantu_sine_unif_ny2560dt0_1nt4.yml
# 1.1783511166847798e-10
# Done

# %%
import numpy as np

l2_constantuv_sine_unif_anis_ny640dt0_4nt1 = 1.9924925526156543e-07
l2_constantuv_sine_unif_anis_ny1280dt0_2nt2 = 4.9746477310711125e-08
l2_constantuv_sine_unif_anis_ny2560dt0_1nt4 = 1.243411840878405e-08
l2_constantuv_sine_unif_ny640dt0_4nt1 = 4.127842019095112e-07
l2_constantuv_sine_unif_ny1280dt0_2nt2 = 1.0320066331553721e-07
l2_constantuv_sine_unif_ny2560dt0_1nt4 = 2.5801233357940707e-08

l2_constantv_sine_unif_anis_ny640dt0_4nt1 = 2.3083857685525355e-07
l2_constantv_sine_unif_anis_ny1280dt0_2nt2 = 5.7711838351816394e-08
l2_constantv_sine_unif_anis_ny2560dt0_1nt4 = 1.4428096727700138e-08
l2_constantv_sine_unif_ny640dt0_4nt1 = 5.3236879391009844e-08
l2_constantv_sine_unif_ny1280dt0_2nt2 = 1.3310007031515332e-08
l2_constantv_sine_unif_ny2560dt0_1nt4 = 3.3275509637461206e-09

l2_constantu_sine_unif_anis_ny640dt0_4nt1 = 9.13780190087281e-09
l2_constantu_sine_unif_anis_ny1280dt0_2nt2 = 9.826794221508725e-10
l2_constantu_sine_unif_anis_ny2560dt0_1nt4 = 1.1783511166847798e-10
l2_constantu_sine_unif_ny640dt0_4nt1 = 9.13780190087281e-09
l2_constantu_sine_unif_ny1280dt0_2nt2 = 9.826794221508725e-10
l2_constantu_sine_unif_ny2560dt0_1nt4 = 1.1783511166847798e-10




# Constant uv: factors anis vs is:
fac1 = l2_constantuv_sine_unif_anis_ny640dt0_4nt1 / l2_constantuv_sine_unif_ny640dt0_4nt1
fac2 = l2_constantuv_sine_unif_anis_ny1280dt0_2nt2 / l2_constantuv_sine_unif_ny1280dt0_2nt2
fac3 = l2_constantuv_sine_unif_anis_ny2560dt0_1nt4 / l2_constantuv_sine_unif_ny2560dt0_1nt4

print('constant uv factors aniso vs iso (less than 1: aniso more accurate): ', fac1, fac2, fac3)

# Constant u: factors anis vs is:
fac1 = l2_constantu_sine_unif_anis_ny640dt0_4nt1 / l2_constantu_sine_unif_ny640dt0_4nt1
fac2 = l2_constantu_sine_unif_anis_ny1280dt0_2nt2 / l2_constantu_sine_unif_ny1280dt0_2nt2
fac3 = l2_constantu_sine_unif_anis_ny2560dt0_1nt4 / l2_constantu_sine_unif_ny2560dt0_1nt4

print('constant u factors aniso vs iso (less than 1: aniso more accurate): ', fac1, fac2, fac3)

# Constant v: factors anis vs is:
fac1 = l2_constantv_sine_unif_anis_ny640dt0_4nt1 / l2_constantv_sine_unif_ny640dt0_4nt1
fac2 = l2_constantv_sine_unif_anis_ny1280dt0_2nt2 / l2_constantv_sine_unif_ny1280dt0_2nt2
fac3 = l2_constantv_sine_unif_anis_ny2560dt0_1nt4 / l2_constantv_sine_unif_ny2560dt0_1nt4

print('constant v factors aniso vs iso (less than 1: aniso more accurate): ', fac1, fac2, fac3)

# Order of convergence anis:
constant_uv_fac1_anis = np.log(l2_constantuv_sine_unif_anis_ny640dt0_4nt1 / l2_constantuv_sine_unif_anis_ny1280dt0_2nt2) / np.log(2)
constant_uv_fac2_anis = np.log(l2_constantuv_sine_unif_anis_ny1280dt0_2nt2 / l2_constantuv_sine_unif_anis_ny2560dt0_1nt4) / np.log(2)
constant_u_fac1_anis = np.log(l2_constantu_sine_unif_anis_ny640dt0_4nt1 / l2_constantu_sine_unif_anis_ny1280dt0_2nt2) / np.log(2)
constant_u_fac2_anis = np.log(l2_constantu_sine_unif_anis_ny1280dt0_2nt2 / l2_constantu_sine_unif_anis_ny2560dt0_1nt4) / np.log(2)
constant_v_fac1_anis = np.log(l2_constantv_sine_unif_anis_ny640dt0_4nt1 / l2_constantv_sine_unif_anis_ny1280dt0_2nt2) / np.log(2)
constant_v_fac2_anis = np.log(l2_constantv_sine_unif_anis_ny1280dt0_2nt2 / l2_constantv_sine_unif_anis_ny2560dt0_1nt4) / np.log(2)

constant_uv_fac1_is = np.log(l2_constantuv_sine_unif_ny640dt0_4nt1 / l2_constantuv_sine_unif_ny1280dt0_2nt2) / np.log(2)
constant_uv_fac2_is = np.log(l2_constantuv_sine_unif_ny1280dt0_2nt2 / l2_constantuv_sine_unif_ny2560dt0_1nt4) / np.log(2)
constant_u_fac1_is = np.log(l2_constantu_sine_unif_ny640dt0_4nt1 / l2_constantu_sine_unif_ny1280dt0_2nt2) / np.log(2)
constant_u_fac2_is = np.log(l2_constantu_sine_unif_ny1280dt0_2nt2 / l2_constantu_sine_unif_ny2560dt0_1nt4) / np.log(2)
constant_v_fac1_is = np.log(l2_constantv_sine_unif_ny640dt0_4nt1 / l2_constantv_sine_unif_ny1280dt0_2nt2) / np.log(2)
constant_v_fac2_is = np.log(l2_constantv_sine_unif_ny1280dt0_2nt2 / l2_constantv_sine_unif_ny2560dt0_1nt4) / np.log(2)


print('order of convergence constant uv aniso: ', constant_uv_fac1_anis, constant_uv_fac2_anis)
print('order of convergence constant uv iso:   ', constant_uv_fac1_is, constant_uv_fac2_is)
print('order of convergence constant u aniso:  ', constant_u_fac1_anis, constant_u_fac2_anis)
print('order of convergence constant u iso:    ', constant_u_fac1_is, constant_u_fac2_is)
print('order of convergence constant v aniso:  ', constant_v_fac1_anis, constant_v_fac2_anis)
print('order of convergence constant v iso:    ', constant_v_fac1_is, constant_v_fac2_is)
# Out:
# constant uv factors aniso vs iso (less than 1: aniso more accurate):  0.48269593249899617 0.4820364105471948 0.48191953602703524
# constant u factors aniso vs iso (less than 1: aniso more accurate):  1.0 1.0 1.0
# constant v factors aniso vs iso (less than 1: aniso more accurate):  4.336065139352166 4.335973543452438 4.335950639042097
# order of convergence constant uv aniso:  2.00190805877778 2.0002901452571327
# order of convergence constant uv iso:    1.9999355133265857 1.999940307088561
# order of convergence constant u aniso:   3.217054416122721 3.0599513581154185
# order of convergence constant u iso:     3.217054416122721 3.0599513581154185
# order of convergence constant v aniso:   1.999945149344022 1.9999862870498062
# order of convergence constant v iso:     1.999914673246038 1.9999786661162011

# %% [markdown]
# Message to Hilary:
#
# Depending on what direction the dominant flow is (whether the dominant flow is already implicit or not?), the solution will become more or less accurate by using anisotropic or isotropic. This is arguably dependent on how big theta is, if we have more explicit, it is more accurate. For constant v, theta is smaller for isotropic than for anisotropic. Thus: less implicit and more accurate. As u=0 there, the v direction is the only one relevant, and this has a notable impact.
#
# When u=v, the anisotropic case is more accurate. So for same OOM velocities, with notably different C (coming from grid spacing differences), the anisotropic case is more accurate. I don't know/think this necessarily applies to a large C from velocities, I wonder if this is worth checking or not.
#
# Any thoughts? Worth checking somehow with small but nonzero u? I have been hesitant to change the velocities themselves so far for these constant velocity cases based on your comment on the AdHImEx paper convergence results. You said to keep the velocity constant throughout, and just change dt to change the Courant number between cases. But this is relevant for convergence results, and not necessarily for comparing errors directly between anisotropic and isotropic.

# %% [markdown]
# # Checking with u=1 instead of 10:

# %% [markdown]
# RDG-HOME+ma836128@UOR002E523383FB MINGW64 ~/OneDrive - University of Reading/Documents/phd/code/2Dadvection (main)
# $ ./convergence_anisotropic_adhimex.sh
# === Running: python run_model.py config_constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(0.0001221997120941788), np.float64(0.9998778002879048))
# Minimum and maximum C over all times: 2.5856, 2.5856
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2\config_constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2.yml
# 5.7500147565327586e-08
# Done
# === Running: python run_model.py config_constantuvsmallu_sine_unif_ny1280dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantuvsmallu_sine_unif_ny1280dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(0.0001221997965918431), np.float64(0.9998778002034086))
# Minimum and maximum C over all times: 2.5856, 2.5856
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_ny1280dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_ny1280dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvsmallu_sine_unif_ny1280dt0_2nt2\config_constantuvsmallu_sine_unif_ny1280dt0_2nt2.yml
# 1.4805792393512355e-08
# Done
# === Running: python run_model.py config_constantuvsmallu_sine_unif_anis_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantuvsmallu_sine_unif_anis_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.0005422757453603763), np.float64(0.9994577242546396))
# Minimum and maximum C over all times: 2.5856, 2.5856
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_anis_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_anis_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvsmallu_sine_unif_anis_ny640dt0_4nt1\config_constantuvsmallu_sine_unif_anis_ny640dt0_4nt1.yml
# 2.2999175870961586e-07
# Done
# === Running: python run_model.py config_constantuvsmallu_sine_unif_ny640dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantuvsmallu_sine_unif_ny640dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.0005422773049987215), np.float64(0.9994577226950014))
# Minimum and maximum C over all times: 2.5856, 2.5856
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_ny640dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_ny640dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvsmallu_sine_unif_ny640dt0_4nt1\config_constantuvsmallu_sine_unif_ny640dt0_4nt1.yml
# 5.922371153169833e-08
# Done
# === Running: python run_model.py config_constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(2.390905574024416e-05), np.float64(0.9999760909442651))
# Minimum and maximum C over all times: 2.5856, 2.5856
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4\config_constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4.yml
# 1.4375176692615502e-08
# Done
# === Running: python run_model.py config_constantuvsmallu_sine_unif_ny2560dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantuvsmallu_sine_unif_ny2560dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(2.390906834140887e-05), np.float64(0.9999760909316584))
# Minimum and maximum C over all times: 2.5856, 2.5856
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_ny2560dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvsmallu_sine_unif_ny2560dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvsmallu_sine_unif_ny2560dt0_1nt4\config_constantuvsmallu_sine_unif_ny2560dt0_1nt4.yml
# 3.7014850282239545e-09
# Done

# %%
# Constant uv small u (u=1 instead of 10, with v still 10)

l2_constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2 = 5.7500147565327586e-08
l2_constantuvsmallu_sine_unif_ny1280dt0_2nt2 = 1.4805792393512355e-08
l2_constantuvsmallu_sine_unif_anis_ny640dt0_4nt1 = 2.2999175870961586e-07
l2_constantuvsmallu_sine_unif_ny640dt0_4nt1 = 5.922371153169833e-08
l2_constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4 = 1.4375176692615502e-08
l2_constantuvsmallu_sine_unif_ny2560dt0_1nt4 = 3.7014850282239545e-09

# Constant uv small u (u=1 instead of 10, with v still 10): factors anis vs is:
fac1 = l2_constantuvsmallu_sine_unif_anis_ny640dt0_4nt1 / l2_constantuvsmallu_sine_unif_ny640dt0_4nt1
fac2 = l2_constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2 / l2_constantuvsmallu_sine_unif_ny1280dt0_2nt2
fac3 = l2_constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4 / l2_constantuvsmallu_sine_unif_ny2560dt0_1nt4

print('constant uv small u factors aniso vs iso (less than 1: aniso more accurate): ', fac1, fac2, fac3)

# Order of convergence anis:
constant_uv_small_u_fac1_anis = np.log(l2_constantuvsmallu_sine_unif_anis_ny640dt0_4nt1 / l2_constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2) / np.log(2)
constant_uv_small_u_fac2_anis = np.log(l2_constantuvsmallu_sine_unif_anis_ny1280dt0_2nt2 / l2_constantuvsmallu_sine_unif_anis_ny2560dt0_1nt4) / np.log(2)

constant_uv_small_u_fac1_is = np.log(l2_constantuvsmallu_sine_unif_ny640dt0_4nt1 / l2_constantuvsmallu_sine_unif_ny1280dt0_2nt2) / np.log(2)
constant_uv_small_u_fac2_is = np.log(l2_constantuvsmallu_sine_unif_ny1280dt0_2nt2 / l2_constantuvsmallu_sine_unif_ny2560dt0_1nt4) / np.log(2)

print('order of convergence constant uv aniso: ', constant_uv_small_u_fac1_anis, constant_uv_small_u_fac2_anis)
print('order of convergence constant uv iso:   ', constant_uv_small_u_fac1_is, constant_uv_small_u_fac2_is)
# Out:
# constant uv small u factors aniso vs iso (less than 1: aniso more accurate):  3.8834404795200532 3.8836251405580406 3.883624162465678
# order of convergence constant uv aniso:  1.9999446024010483 1.9999859694525064
# order of convergence constant uv iso:    2.000013202198406 1.9999856061092056

# %% [markdown]
# # What if I just have different velocities in x and y? I.e., no 10x finer grid in y direction?
#
# Arguably, the larger number of points in y also increased the accuracy in the y direction.
#
# Plus, this would be a thing to test in general, whether just based on the velocity it can make a difference. With the constant velocities setup, I can easily just check with the analytic solution, so I don't have to worry about an integer number of revolutions etc.
#
# In the below, I have the same x and y grid spacing (64, 128, 256), but now with u=10 and v=100. These are the 'large v' simulations.

# %% [markdown]
# RDG-HOME+ma836128@UOR002E523383FB MINGW64 ~/OneDrive - University of Reading/Documents/phd/code/2Dadvection (main)
# $ ./convergence_anisotropic_adhimex.sh
# === Running: python run_model.py config_constantuvlargev_sine_unif_anis_ny128dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantuvlargev_sine_unif_anis_ny128dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(8.847620776103963e-05), np.float64(0.9999115237922395))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_anis_ny128dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_anis_ny128dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvlargev_sine_unif_anis_ny128dt0_2nt2\config_constantuvlargev_sine_unif_anis_ny128dt0_2nt2.yml
# 5.7521698905168305e-05
# Done
# === Running: python run_model.py config_constantuvlargev_sine_unif_ny128dt0_2nt2 ===
# Running model...
# See output file ./output/dated/20260917/constantuvlargev_sine_unif_ny128dt0_2nt2/out.log
# Min and max tracer at final time step: (np.float64(8.801600151206348e-05), np.float64(0.9999119839984884))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_ny128dt0_2nt2/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_ny128dt0_2nt2/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvlargev_sine_unif_ny128dt0_2nt2\config_constantuvlargev_sine_unif_ny128dt0_2nt2.yml
# 1.9544512077672012e-05
# Done
# === Running: python run_model.py config_constantuvlargev_sine_unif_anis_ny64dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantuvlargev_sine_unif_anis_ny64dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.00015229454610337758), np.float64(0.9998477054538969))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_anis_ny64dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_anis_ny64dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvlargev_sine_unif_anis_ny64dt0_4nt1\config_constantuvlargev_sine_unif_anis_ny64dt0_4nt1.yml
# 0.0002291954253468841
# Done
# === Running: python run_model.py config_constantuvlargev_sine_unif_ny64dt0_4nt1 ===
# Running model...
# See output file ./output/dated/20260917/constantuvlargev_sine_unif_ny64dt0_4nt1/out.log
# Min and max tracer at final time step: (np.float64(0.0001566563645150482), np.float64(0.9998433436354851))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_ny64dt0_4nt1/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_ny64dt0_4nt1/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvlargev_sine_unif_ny64dt0_4nt1\config_constantuvlargev_sine_unif_ny64dt0_4nt1.yml
# 7.778111295048968e-05
# Done
# === Running: python run_model.py config_constantuvlargev_sine_unif_anis_ny256dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantuvlargev_sine_unif_anis_ny256dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(4.4429034119977444e-05), np.float64(0.9999555709658814))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_anis_ny256dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_anis_ny256dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvlargev_sine_unif_anis_ny256dt0_1nt4\config_constantuvlargev_sine_unif_anis_ny256dt0_1nt4.yml
# 1.439443288797872e-05
# Done
# === Running: python run_model.py config_constantuvlargev_sine_unif_ny256dt0_1nt4 ===
# Running model...
# See output file ./output/dated/20260917/constantuvlargev_sine_unif_ny256dt0_1nt4/out.log
# Min and max tracer at final time step: (np.float64(4.442244810199407e-05), np.float64(0.9999555775518987))
# Minimum and maximum C over all times: 2.816, 2.816
# Done
# Plotting done.
# See error log C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_ny256dt0_1nt4/error.log
# Running error analysis for dir=C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection/output/dated/20260917/constantuvlargev_sine_unif_ny256dt0_1nt4/ and setting=finaltoanalytic
# Config file found: C:\Users\ma836128\OneDrive - University of Reading\Documents\phd\code\2Dadvection\output\dated\20260917\constantuvlargev_sine_unif_ny256dt0_1nt4\config_constantuvlargev_sine_unif_ny256dt0_1nt4.yml
# 4.8923740217118055e-06
# Done

# %%
l2_constantuvlargev_sine_unif_anis_ny128dt0_2nt2 = 5.7521698905168305e-05
l2_constantuvlargev_sine_unif_ny128dt0_2nt2 = 1.9544512077672012e-05
l2_constantuvlargev_sine_unif_anis_ny64dt0_4nt1 = 0.0002291954253468841
l2_constantuvlargev_sine_unif_ny64dt0_4nt1 = 7.778111295048968e-05
l2_constantuvlargev_sine_unif_anis_ny256dt0_1nt4 = 1.439443288797872e-05
l2_constantuvlargev_sine_unif_ny256dt0_1nt4 = 4.8923740217118055e-06



# Constant uv large v (with now same grid spacing in x and y, this was not the case with the u=1 case before: there ny was 10 times nx) factors anis vs is:
fac1 = l2_constantuvlargev_sine_unif_anis_ny64dt0_4nt1 / l2_constantuvlargev_sine_unif_ny64dt0_4nt1
fac2 = l2_constantuvlargev_sine_unif_anis_ny128dt0_2nt2 / l2_constantuvlargev_sine_unif_ny128dt0_2nt2
fac3 = l2_constantuvlargev_sine_unif_anis_ny256dt0_1nt4 / l2_constantuvlargev_sine_unif_ny256dt0_1nt4

print('constant uv large v factors aniso vs iso (less than 1: aniso more accurate): ', fac1, fac2, fac3)

# Order of convergence anis:
constant_uv_large_v_fac1_anis = np.log(l2_constantuvlargev_sine_unif_anis_ny64dt0_4nt1 / l2_constantuvlargev_sine_unif_anis_ny128dt0_2nt2) / np.log(2)
constant_uv_large_v_fac2_anis = np.log(l2_constantuvlargev_sine_unif_anis_ny128dt0_2nt2 / l2_constantuvlargev_sine_unif_anis_ny256dt0_1nt4) / np.log(2)

constant_uv_large_v_fac1_is = np.log(l2_constantuvlargev_sine_unif_ny64dt0_4nt1 / l2_constantuvlargev_sine_unif_ny128dt0_2nt2) / np.log(2)
constant_uv_large_v_fac2_is = np.log(l2_constantuvlargev_sine_unif_ny128dt0_2nt2 / l2_constantuvlargev_sine_unif_ny256dt0_1nt4) / np.log(2)

print('order of convergence constant uv large v aniso: ', constant_uv_large_v_fac1_anis, constant_uv_large_v_fac2_anis)
print('order of convergence constant uv large v iso:   ', constant_uv_large_v_fac1_is, constant_uv_large_v_fac2_is)
# Out:
# constant uv large v factors aniso vs iso (less than 1: aniso more accurate):  2.9466719702606308 2.943112556433787 2.9422184044183552
# order of convergence constant uv large v aniso:  1.9944000571783556 1.9985953357431194
# order of convergence constant uv large v iso:    1.9926563094136138 1.9981569615218664
